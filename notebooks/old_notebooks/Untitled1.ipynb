# %%
import torch
import matplotlib.pyplot as plt
import seaborn as sns

# %%
g = torch.randn(32768)

# %%
def fn(x, k):
    return x.abs() ** k * x.sign()

# %%
plt.figure(figsize=(16, 16))
sns.kdeplot(g)
sns.kdeplot(fn(g, 1.2))
sns.kdeplot(fn(g, 0.8))
# Out:
# <AxesSubplot:ylabel='Density'>
