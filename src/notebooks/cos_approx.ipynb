# %%
import numpy as np
import matplotlib.pyplot as plt

import math

# %%
width = 2
ntime = 64

# %%
def gaussian_profile(ntime: int, width: float):
    x: np.ndarray = np.linspace(-ntime // 2, ntime // 2, ntime)  # type: ignore
    g = np.exp(-((x / width) ** 2)) + 1e-9
    return g

# %%
period = 12 + np.random.rand() * ((ntime - 24) // 2)
fwhm = np.random.rand() * (period / 2)

period, fwhm
# Out:
# (19.509999379569535, 6.365270235234325)

# %%
width = 0.42466090014400953 * fwhm

# %%
ntime / period
# Out:
# 3.2803691458350053

# %%
g = gaussian_profile(ntime, width)
# g = p.copy()
# g = np.zeros_like(p)

# plt.plot(g)
# plt.show()
assert fwhm * 2 < period, (fwhm * 2, period)
assert ntime // period > 1

# c = 2 * fwhm
# for i in range(int(ntime / period)):
#     c = period + 2 * fwhm
#     print(c)
# #     shift = c - ntime / 2
#     print(shift)
#     g = g + np.roll(g, int(c))
# for i in range(int(ntime / period) - 1):


#     g = g + np.roll(g, int(period))
    
    
plt.plot(g)

# %%
fwhm_2
# Out:
# 28.25784054037139

# %%
new_c += period

# %%
g0 = np.roll(g0, shift)

# %%
plt.plot(g0)

# %%
# g0 = gaussian_profile(ntime, width)

# fwhm = 2.3548200450309493 * width * 2

# shift = int(fwhm / 2 - len(g0) / 2)

# g0 = np.roll(g0, shift)

# g = np.zeros_like(g0)
# g = g + g0

# %%
for i in range(1, ntime // period):
    g_ = np.roll(g0, i * period)
    g = g + g_
    plt.plot(g)
    plt.show()

# %%
plt.plot(g)
plt.show()
